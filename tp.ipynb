# %%
from turtle import left
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


N=1001;
T=1.0/10000.00  #0.0001 segundos
PFreq = np.linspace(0,10000,N)
x= np.arange(0,0.1,T)
xff= np.append(x,0.1)


arregloCalamarFourier = np.fft.fft(arregloCalamar)


rectIfft=[]
 
b=5;
for n in range(0,1001):
    rectIfft.append((1/b)*np.sinc((n)*(1/b)))
 
rectFourier= np.fft.fft(rectIfft)
mult = arregloCalamarFourier*rectFourier
 
ifftMult=np.fft.ifft(mult)
plt.plot(xff,rectIfft)

plt.title('Filtro sinc')
# Out:
# Text(0.5, 1.0, 'Filtro sinc')
